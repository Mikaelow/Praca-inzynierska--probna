# %% [markdown]
# # Initialize data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
db = pd.read_csv("Added data.csv",sep=';')

# %%
db #showing database
# Out:
#           Time      A_P1      A_P2         B         C         D          E  \
# 0      0.00000 -1.920661 -8.439848  2.976091 -0.315936 -1.236104 -15.970842
# 1      0.00003  0.907933 -8.270332  1.403297 -1.518895 -0.750377   3.912063
# 2      0.00006  3.118851 -7.559020 -0.319664 -2.070466 -0.585118  21.081397
# 3      0.00009  4.890883 -6.261887 -0.999223 -2.263551 -0.941613  33.281290
# 4      0.00012  5.761676 -4.681169 -0.326351 -2.003942 -1.574369  37.888655
# ...        ...       ...       ...       ...       ...       ...        ...
# 32197  0.96591 -1.473239  0.120947  1.587979  3.219263  3.804088  -0.403454
# 32198  0.96594 -1.064499 -0.832881  0.900456  4.496452  1.960730   6.579299
# 32199  0.96597 -0.238564 -2.126691 -0.037394  4.887121  0.150196  16.562111
# 32200  0.96600  0.571654 -3.033177 -0.884484  4.760790 -1.322922  23.892387
# 32201  0.96603  0.235584 -3.493258 -2.073583  3.850445 -1.886883  31.019453
#
#                F
# 0      10.932161
# 1       8.571077
# ...

# %%
db.hist(bins=60, figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'Time'}>,
#         <Axes: title={'center': 'A_P1'}>,
#         <Axes: title={'center': 'A_P2'}>],
#        [<Axes: title={'center': 'B'}>, <Axes: title={'center': 'C'}>,
#         <Axes: title={'center': 'D'}>],
#        [<Axes: title={'center': 'E'}>, <Axes: title={'center': 'F'}>,
#         <Axes: >]], dtype=object)

# %% [markdown]
# # Creating histograms

# %%
sns.histplot(db[['A_P1', 'A_P2', 'B', 'C', 'D', 'E', 'F']], bins=1000)
plt.xlim(-10, 10)
# Out:
# (-10.0, 10.0)

# %% [markdown]
# ## Choosing most differend data to `A_P1`

# %%
sns.histplot(db[['A_P1','B','F']])
plt.xlim(-10, 10)
# Out:
# (-10.0, 10.0)

# %% [markdown]
#  ## Creating boxplots

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 8))  # 2 wiersze, 1 kolumna
#boxplot with showfliers on 
sns.boxplot(ax=axs[0], data=db[['A_P1', 'A_P2', 'B', 'C', 'D', 'E', 'F']])
axs[0].set_title("Boxplot with showfliers on")

#boxplot without showfliers 
sns.boxplot(ax=axs[1], data=db[['A_P1', 'A_P2', 'B', 'C', 'D', 'E', 'F']],showfliers=False)
axs[1].set_title("Boxplot without showfliers on")
# Out:
# Text(0.5, 1.0, 'Boxplot without showfliers on')

# %%
#boxplot without showfliers and F bearing
sns.boxplot(data=db[['A_P1', 'A_P2', 'B', 'C', 'D', 'E']],showfliers=False)
plt.title("Boxplot without showfliers on and F bearing")
# Out:
# Text(0.5, 1.0, 'Boxplot without showfliers on and F bearing')
